# %%
# Importing our dependencies
import csv
import pandas as pd
import numpy as np
import sqlite3
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Reading our CSV file and putting it into a variable
tokyo = pd.read_csv("Resources/summary_listings.csv")
tokyo.head()
# Out:
#         id                                               name   host_id  \
# 0   197677  Rental unit in Sumida · ★4.78 · 1 bedroom · 2 ...    964081
# 1   776070  Home in Kita-ku · ★4.98 · 1 bedroom · 1 bed · ...    801494
# 2  3427384  Rental unit in Edogawa · ★4.82 · 1 bedroom · 2...  13018876
# 3   905944  Rental unit in Shibuya · ★4.76 · 2 bedrooms · ...   4847803
# 4  3514008  Rental unit in Arakawa-ku · ★4.86 · 1 bedroom ...  17694529
#
#              host_name  neighbourhood_group neighbourhood  latitude  \
# 0      Yoshimi & Marek                  NaN     Sumida Ku  35.71707
# 1                  Kei                  NaN       Kita Ku  35.73844
# 2            Masakatsu                  NaN    Edogawa Ku  35.68374
# 3  Best Stay In Tokyo!                  NaN    Shibuya Ku  35.67878
# 4                Hisao                  NaN    Arakawa Ku  35.72672
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  139.82608  Entire home/apt  11000               3                173
# 1  139.76917     Private room   7208               3                243
# 2  139.85971  Entire home/apt   7847               2                100
# 3  139.67847  Entire home/apt  23066               3                186
# 4  139.78201  Entire home/apt   2871               1                269
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2023-05-30               1.21                               1
# 1  2023-06-20               1.89                               1
# 2  2023-05-22               0.93                               2
# 3  2023-06-26               1.49                               5
# 4  2023-06-08               2.59                               9
#
#    availability_365  number_of_reviews_ltm  \
# 0                24                      8
# 1                67                     15
# 2               231                     19
# 3               229                      1
# 4                11                     29
#
#                                              license
# 0                                         M130003350
# 1                                                NaN
# 2  Hotels and Inns Business Act | 東京都江戸川区保健所 | 18...
# 3  Hotels and Inns Business Act | 渋谷区保健所長 | 31渋健生...
# 4  Hotels and Inns Business Act | 東京都荒川区保健所 | 31荒...

# %%
# Deleting unwanted columns and making sure it stays in place
columns_to_delete = ['neighbourhood_group', 'last_review', 'calculated_host_listings_count', 
                     'number_of_reviews_ltm', 'license']
tokyo.drop(columns=columns_to_delete, inplace=True)

tokyo.head()
# Out:
#         id                                               name   host_id  \
# 0   197677  Rental unit in Sumida · ★4.78 · 1 bedroom · 2 ...    964081
# 1   776070  Home in Kita-ku · ★4.98 · 1 bedroom · 1 bed · ...    801494
# 2  3427384  Rental unit in Edogawa · ★4.82 · 1 bedroom · 2...  13018876
# 3   905944  Rental unit in Shibuya · ★4.76 · 2 bedrooms · ...   4847803
# 4  3514008  Rental unit in Arakawa-ku · ★4.86 · 1 bedroom ...  17694529
#
#              host_name neighbourhood  latitude  longitude        room_type  \
# 0      Yoshimi & Marek     Sumida Ku  35.71707  139.82608  Entire home/apt
# 1                  Kei       Kita Ku  35.73844  139.76917     Private room
# 2            Masakatsu    Edogawa Ku  35.68374  139.85971  Entire home/apt
# 3  Best Stay In Tokyo!    Shibuya Ku  35.67878  139.67847  Entire home/apt
# 4                Hisao    Arakawa Ku  35.72672  139.78201  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0  11000               3                173               1.21
# 1   7208               3                243               1.89
# 2   7847               2                100               0.93
# 3  23066               3                186               1.49
# 4   2871               1                269               2.59
#
#    availability_365
# 0                24
# 1                67
# 2               231
# 3               229
# 4                11

# %%
# Splitting 'name' column by '·'
tokyo[['name', 'ratings', 'bedrooms', 'beds', 'baths']] = tokyo['name'].str.split('·', expand=True)

#Removing the star from the ratings row
def remove_star(value):
    if isinstance(value, str):
        return value.replace('★', '').strip()
    return value
        
tokyo = tokyo.applymap(remove_star)
tokyo.head()
# Out:
# C:\Users\sophi\AppData\Local\Temp\ipykernel_14492\3849390388.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   tokyo = tokyo.applymap(remove_star)
#         id                       name   host_id            host_name  \
# 0   197677      Rental unit in Sumida    964081      Yoshimi & Marek
# 1   776070            Home in Kita-ku    801494                  Kei
# 2  3427384     Rental unit in Edogawa  13018876            Masakatsu
# 3   905944     Rental unit in Shibuya   4847803  Best Stay In Tokyo!
# 4  3514008  Rental unit in Arakawa-ku  17694529                Hisao
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0     Sumida Ku  35.71707  139.82608  Entire home/apt  11000               3
# 1       Kita Ku  35.73844  139.76917     Private room   7208               3
# 2    Edogawa Ku  35.68374  139.85971  Entire home/apt   7847               2
# 3    Shibuya Ku  35.67878  139.67847  Entire home/apt  23066               3
# 4    Arakawa Ku  35.72672  139.78201  Entire home/apt   2871               1
#
#    number_of_reviews  reviews_per_month  availability_365 ratings    bedrooms  \
# 0                173               1.21                24    4.78   1 bedroom
# 1                243               1.89                67    4.98   1 bedroom
# 2                100               0.93               231    4.82   1 bedroom
# 3                186               1.49               229    4.76  2 bedrooms
# 4                269               2.59                11    4.86   1 bedroom
#
#      beds          baths
# 0  2 beds         1 bath
# 1   1 bed  1 shared bath
# 2  2 beds      1.5 baths
# 3  4 beds         1 bath
# 4  2 beds         1 bath

# %%
##Checking the object types
tokyo.dtypes
# Out:
# id                     int64
# name                  object
# host_id                int64
# host_name             object
# neighbourhood         object
# latitude             float64
# longitude            float64
# room_type             object
# price                  int64
# minimum_nights         int64
# number_of_reviews      int64
# reviews_per_month    float64
# availability_365       int64
# ratings               object
# bedrooms              object
# beds                  object
# baths                 object
# dtype: object

# %%
# Changing the types to float from object for plotting.
tokyo['ratings'] = tokyo['ratings'].str.extract('(\d+\.\d+|\d+)').astype(float)
tokyo['bedrooms'] = tokyo['bedrooms'].str.extract('(\d+)').astype(float)
tokyo['beds'] = tokyo['beds'].str.extract('(\d+)').astype(float)
tokyo['baths'] = tokyo['baths'].str.extract('(\d+)').astype(float)

# %%
#Taking out values od 0 or that are blank
tokyo.replace(0, pd.NA, inplace=True)
tokyo.dropna(axis=0, how='any', inplace=True)
tokyo.head(10)
# Out:
#          id                       name   host_id            host_name  \
# 0    197677      Rental unit in Sumida    964081      Yoshimi & Marek
# 1    776070            Home in Kita-ku    801494                  Kei
# 2   3427384     Rental unit in Edogawa  13018876            Masakatsu
# 3    905944     Rental unit in Shibuya   4847803  Best Stay In Tokyo!
# 4   3514008  Rental unit in Arakawa-ku  17694529                Hisao
# 5   1016831           Home in Setagaya   5596383               Wakana
# 6   3563698     Rental unit in Machida  11583876                  Ken
# 8   3572139         Home in Toshima-ku  15514130                 Tomo
# 9   1249571            Home in Shibuya   6809418                 Yume
# 10  3623844     Rental unit in Edogawa  13018876            Masakatsu
#
#    neighbourhood   latitude   longitude        room_type  price  \
# 0      Sumida Ku  35.717070  139.826080  Entire home/apt  11000
# 1        Kita Ku  35.738440  139.769170     Private room   7208
# 2     Edogawa Ku  35.683740  139.859710  Entire home/apt   7847
# 3     Shibuya Ku  35.678780  139.678470  Entire home/apt  23066
# 4     Arakawa Ku  35.726720  139.782010  Entire home/apt   2871
# 5    Setagaya Ku  35.658000  139.671340     Private room  16000
# 6    Machida Shi  35.589110  139.480230  Entire home/apt   4814
# 8     Toshima Ku  35.727843  139.734084  Entire home/apt  31229
# 9     Shibuya Ku  35.651110  139.721650  Entire home/apt  54782
# 10    Edogawa Ku  35.683580  139.859850  Entire home/apt   7538
#
#     minimum_nights number_of_reviews  reviews_per_month availability_365  \
# 0                3               173               1.21               24
# 1                3               243               1.89               67
# 2                2               100               0.93              231
# 3                3               186               1.49              229
# 4                1               269               2.59               11
# 5                1               244               1.96              101
# 6                3               120               1.11              224
# 8                3               201               2.10              196
# 9                7               116               0.97              189
# 10               2                77               0.77              210
#
#     ratings  bedrooms beds baths
# 0      4.78       1.0  2.0   1.0
# 1      4.98       1.0  1.0   1.0
# 2      4.82       1.0  2.0   1.0
# 3      4.76       2.0  4.0   1.0
# 4      4.86       1.0  2.0   1.0
# 5      4.94       1.0  2.0   1.0
# 6      4.87       1.0  2.0   1.0
# 8      4.85       3.0  6.0   1.0
# 9      4.96       1.0  1.0   1.0
# 10     4.86       1.0  4.0   1.0

# %%
# Reorganizing columns into order of identification and location, host information, property information, booking and review information, and rating and accomodation details
new_column_order = [
    'id', 'name', 'neighbourhood', 'latitude', 'longitude',
    'host_id', 'host_name', 'room_type', 'price',
    'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365',
    'ratings', 'bedrooms', 'beds', 'baths'
]

tokyo_df = tokyo[new_column_order]
tokyo_df.head()
# Out:
#         id                       name neighbourhood  latitude  longitude  \
# 0   197677      Rental unit in Sumida     Sumida Ku  35.71707  139.82608
# 1   776070            Home in Kita-ku       Kita Ku  35.73844  139.76917
# 2  3427384     Rental unit in Edogawa    Edogawa Ku  35.68374  139.85971
# 3   905944     Rental unit in Shibuya    Shibuya Ku  35.67878  139.67847
# 4  3514008  Rental unit in Arakawa-ku    Arakawa Ku  35.72672  139.78201
#
#     host_id            host_name        room_type  price  minimum_nights  \
# 0    964081      Yoshimi & Marek  Entire home/apt  11000               3
# 1    801494                  Kei     Private room   7208               3
# 2  13018876            Masakatsu  Entire home/apt   7847               2
# 3   4847803  Best Stay In Tokyo!  Entire home/apt  23066               3
# 4  17694529                Hisao  Entire home/apt   2871               1
#
#   number_of_reviews  reviews_per_month availability_365  ratings  bedrooms  \
# 0               173               1.21               24     4.78       1.0
# 1               243               1.89               67     4.98       1.0
# 2               100               0.93              231     4.82       1.0
# 3               186               1.49              229     4.76       2.0
# 4               269               2.59               11     4.86       1.0
#
#   beds baths
# 0  2.0   1.0
# 1  1.0   1.0
# 2  2.0   1.0
# 3  4.0   1.0
# 4  2.0   1.0

# %%
tokyo_df_organized = pd.DataFrame(tokyo_df)
csv_path = 'Resources/updated_summarylist.csv'
tokyo_df_organized.to_csv(csv_path, index = False)

# %%
# Create sqlite file
path = 'Resources/tokyoAirbnb.sqlite'
conn = sqlite3.connect(path)

# Write the DataFrame to the database
tokyo_df_organized.to_sql(name='tokyoAirbnb', con=conn, if_exists='replace', index=False)

# Close the connection
conn.close()

# %%
#Copying our DF for use
tokyo_df = tokyo_df_organized.copy()
tokyo_df.head()
# Out:
#         id                       name neighbourhood  latitude  longitude  \
# 0   197677      Rental unit in Sumida     Sumida Ku  35.71707  139.82608
# 1   776070            Home in Kita-ku       Kita Ku  35.73844  139.76917
# 2  3427384     Rental unit in Edogawa    Edogawa Ku  35.68374  139.85971
# 3   905944     Rental unit in Shibuya    Shibuya Ku  35.67878  139.67847
# 4  3514008  Rental unit in Arakawa-ku    Arakawa Ku  35.72672  139.78201
#
#     host_id            host_name        room_type  price  minimum_nights  \
# 0    964081      Yoshimi & Marek  Entire home/apt  11000               3
# 1    801494                  Kei     Private room   7208               3
# 2  13018876            Masakatsu  Entire home/apt   7847               2
# 3   4847803  Best Stay In Tokyo!  Entire home/apt  23066               3
# 4  17694529                Hisao  Entire home/apt   2871               1
#
#   number_of_reviews  reviews_per_month availability_365  ratings  bedrooms  \
# 0               173               1.21               24     4.78       1.0
# 1               243               1.89               67     4.98       1.0
# 2               100               0.93              231     4.82       1.0
# 3               186               1.49              229     4.76       2.0
# 4               269               2.59               11     4.86       1.0
#
#   beds baths
# 0  2.0   1.0
# 1  1.0   1.0
# 2  2.0   1.0
# 3  4.0   1.0
# 4  2.0   1.0

# %%
#Creating a Bar Chart based on the Neighborhood and number of listings.

#Creating a listing count of each neighborhood and sorting it into descending order with the top 15
neighborhood_counts = tokyo_df['neighbourhood'].value_counts()
neighborhood_counts_sorted = neighborhood_counts.sort_values(ascending=False)
top_neighborhoods = neighborhood_counts_sorted.head(15)

# Plotting a bar chart using MatPlotLib

plt.figure(figsize=(10, 6))
top_neighborhoods.plot(kind='bar', color='skyblue')
plt.title('Number of Listings by Neighborhood in Tokyo')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Listings')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Creating a Histogram to show the overall distribution of price
tokyo_df = tokyo_df[tokyo_df['price'] < 100000] 
## Using Matplotlib 
plt.figure(figsize=(10, 6))
sns.histplot(tokyo_df['price'], bins=10, color='skyblue', edgecolor='black', kde=False)
plt.title('Histogram of Prices in Tokyo')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sophi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
top_neighborhoods = tokyo_df.nlargest(15, 'price')

# %%
# Creating box plot
#First finding average 
tokyo_df['neighbourhood'] = tokyo_df['neighbourhood'].str.strip()

# Calculate the average price for each neighborhood and grouping them to what neighborhood
average_prices = tokyo_df.groupby('neighbourhood')['price'].mean().reset_index()

# Rename columns for clarity
average_prices.columns = ['neighbourhood', 'average_price']
top_neighbourhoods = average_prices.sort_values(by='average_price', ascending=False).head(15)
top_neighbourhoods

# %%
#Creating the boxplot and plotting it with sns and matplotlib
plt.figure(figsize=(12, 8))
sns.boxplot(data=top_neighborhoods, x='neighbourhood', y='price')
plt.xticks(rotation=45, ha='right')
plt.title('Box Plot of Prices for Top 15 Neighborhoods in Tokyo')
plt.xlabel('Neighborhoods')
plt.ylabel('Price')
plt.tight_layout()
plt.show()
